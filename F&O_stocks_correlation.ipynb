# %% [markdown]
# #Aim
#
# To find the heavily correlated f&o stocks.
#
# I'll be using Google Colab for the project and recommend the same if you want to follow along!
#
# ---

# %% [markdown]
# For this project, I'll be using the Yahoo Finance API.

# %%
# Installing the yfinance module to the Jupyter notebook
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.7/dist-packages (0.1.70)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.21.5)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in /usr/local/lib/python3.7/dist-packages (from yfinance) (1.3.5)
# Requirement already satisfied: requests>=2.26 in /usr/local/lib/python3.7/dist-packages (from yfinance) (2.27.1)
# Requirement already satisfied: lxml>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from yfinance) (4.8.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.24.0->yfinance) (2018.9)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.15.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.26->yfinance) (2.10)

# %%
# Importing all the neccesary modules
import yfinance as yf
import pandas as pd
import time

# %% [markdown]
# I've stored all the stock names in a `.txt` file. So before we extract all the stock prices for each year, we'll have to convert this file into a `.csv` file.

# %%
# Code to convert the .txt file to a .csv file
stocks = []
file = open("/content/f&o stocks.txt", "r")

for line in file.readlines():
  stocks.append(line.split("\t"))

df = pd.DataFrame(stocks, columns = ["Stock Name", "Stock Symbol"])

symbol_list = []
for symbol in df.loc[:, "Stock Symbol"]:
  symbol_list.append(symbol.replace("\n", ".NS")) # Here am adding .NS to each symbol as he represents that the symbol belongs to NSE

df.loc[:, "Stock Symbol"] = symbol_list
df.to_csv("F&O stocks.csv", index = False)

# %% [markdown]
# With the above code finishing it's execution, you'll see a `.csv` file with the name `F&O stocks.csv` in the Files folder to your left.
#
# ---

# %% [markdown]
# Next, we copy the path of the `F&O stocks.csv` file, open it as a pandas dataframe, and store the data in the `Stock Symbol`column as a variable

# %%
# Opening the F&O stocks.csv file as a pandas dtaframe
fNo_stocks_df = pd.read_csv("/content/F&O stocks.csv")

# Storing all the symbols in one variable
fNo_stocks = fNo_stocks_df.loc[:, "Stock Symbol"]

# %% [markdown]
# Next, we get the `closing` prices of the stocks since their listing and store it in a list.

# %%
# Downloading the price closes since the listing of the stock
stocks_data = []

for stock in fNo_stocks:
  print(stock) # I am printing the stock name here just to know which stock is the program currently on
  stocks_data.append(yf.download(stock)["Close"])
# Out:
# AARTIIND.NS
# [*********************100%***********************]  1 of 1 completed
# ABB.NS
# [*********************100%***********************]  1 of 1 completed
# ABBOTINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# ABCAPITAL.NS
# [*********************100%***********************]  1 of 1 completed
# ABFRL.NS
# [*********************100%***********************]  1 of 1 completed
# ACC.NS
# [*********************100%***********************]  1 of 1 completed
# ADANIENT.NS
# [*********************100%***********************]  1 of 1 completed
# ADANIPORTS.NS
# [*********************100%***********************]  1 of 1 completed
# ALKEM.NS
# [*********************100%***********************]  1 of 1 completed
# AMARAJABAT.NS
# [*********************100%***********************]  1 of 1 completed
# AMBUJACEM.NS
# [*********************100%***********************]  1 of 1 completed
# APLLTD.NS
# [*********************100%***********************]  1 of 1 completed
# APOLLOHOSP.NS
# [*********************100%***********************]  1 of 1 completed
# APOLLOTYRE.NS
# [*********************100%***********************]  1 of 1 completed
# ASHOKLEY.NS
# [*********************100%***********************]  1 of 1 completed
# ASIANPAINT.NS
# [*********************100%***********************]  1 of 1 completed
# ASTRAL.NS
# [*********************100%***********************]  1 of 1 completed
# ATUL.NS
# [*********************100%***********************]  1 of 1 completed
# AUBANK.NS
# [*********************100%***********************]  1 of 1 completed
# AUROPHARMA.NS
# [*********************100%***********************]  1 of 1 completed
# AXISBANK.NS
# [*********************100%***********************]  1 of 1 completed
# BAJAJ-AUTO.NS
# [*********************100%***********************]  1 of 1 completed
# BAJAJFINSV.NS
# [*********************100%***********************]  1 of 1 completed
# BAJFINANCE.NS
# [*********************100%***********************]  1 of 1 completed
# BALKRISIND.NS
# [*********************100%***********************]  1 of 1 completed
# BALRAMCHIN.NS
# [*********************100%***********************]  1 of 1 completed
# BANDHANBNK.NS
# [*********************100%***********************]  1 of 1 completed
# BANKBARODA.NS
# [*********************100%***********************]  1 of 1 completed
# BATAINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# BEL.NS
# [*********************100%***********************]  1 of 1 completed
# BERGEPAINT.NS
# [*********************100%***********************]  1 of 1 completed
# BHARATFORG.NS
# [*********************100%***********************]  1 of 1 completed
# BHARTIARTL.NS
# [*********************100%***********************]  1 of 1 completed
# BHEL.NS
# [*********************100%***********************]  1 of 1 completed
# BIOCON.NS
# [*********************100%***********************]  1 of 1 completed
# BOSCHLTD.NS
# [*********************100%***********************]  1 of 1 completed
# BPCL.NS
# [*********************100%***********************]  1 of 1 completed
# BRITANNIA.NS
# [*********************100%***********************]  1 of 1 completed
# BSOFT.NS
# [*********************100%***********************]  1 of 1 completed
# CADILAHC.NS
# [*********************100%***********************]  1 of 1 completed
# CANBK.NS
# [*********************100%***********************]  1 of 1 completed
# CANFINHOME.NS
# [*********************100%***********************]  1 of 1 completed
# CHAMBLFERT.NS
# [*********************100%***********************]  1 of 1 completed
# CHOLAFIN.NS
# [*********************100%***********************]  1 of 1 completed
# CIPLA.NS
# [*********************100%***********************]  1 of 1 completed
# COALINDIA.NS
# [*********************100%***********************]  1 of 1 completed
# COFORGE.NS
# [*********************100%***********************]  1 of 1 completed
# COLPAL.NS
# [*********************100%***********************]  1 of 1 completed
# CONCOR.NS
# [*********************100%***********************]  1 of 1 completed
# COROMANDEL.NS
# [*********************100%***********************]  1 of 1 completed
# CROMPTON.NS
# [*********************100%***********************]  1 of 1 completed
# CUB.NS
# [*********************100%***********************]  1 of 1 completed
# CUMMINSIND.NS
# [*********************100%***********************]  1 of 1 completed
# DABUR.NS
# [*********************100%***********************]  1 of 1 completed
# DALBHARAT.NS
# [*********************100%***********************]  1 of 1 completed
# DEEPAKNTR.NS
# [*********************100%***********************]  1 of 1 completed
# DELTACORP.NS
# [*********************100%***********************]  1 of 1 completed
# DIVISLAB.NS
# [*********************100%***********************]  1 of 1 completed
# DIXON.NS
# [*********************100%***********************]  1 of 1 completed
# DLF.NS
# [*********************100%***********************]  1 of 1 completed
# DRREDDY.NS
# [*********************100%***********************]  1 of 1 completed
# EICHERMOT.NS
# [*********************100%***********************]  1 of 1 completed
# ESCORTS.NS
# [*********************100%***********************]  1 of 1 completed
# EXIDEIND.NS
# [*********************100%***********************]  1 of 1 completed
# FEDERALBNK.NS
# [*********************100%***********************]  1 of 1 completed
# FSL.NS
# [*********************100%***********************]  1 of 1 completed
# GAIL.NS
# [*********************100%***********************]  1 of 1 completed
# GLENMARK.NS
# [*********************100%***********************]  1 of 1 completed
# GMRINFRA.NS
# [*********************100%***********************]  1 of 1 completed
# GNFC.NS
# [*********************100%***********************]  1 of 1 completed
# GODREJCP.NS
# [*********************100%***********************]  1 of 1 completed
# GODREJPROP.NS
# [*********************100%***********************]  1 of 1 completed
# GRANULES.NS
# [*********************100%***********************]  1 of 1 completed
# GRASIM.NS
# [*********************100%***********************]  1 of 1 completed
# GSPL.NS
# [*********************100%***********************]  1 of 1 completed
# GUJGASLTD.NS
# [*********************100%***********************]  1 of 1 completed
# HAL.NS
# [*********************100%***********************]  1 of 1 completed
# HAVELLS.NS
# [*********************100%***********************]  1 of 1 completed
# HCLTECH.NS
# [*********************100%***********************]  1 of 1 completed
# HDFC.NS
# [*********************100%***********************]  1 of 1 completed
# HDFCAMC.NS
# [*********************100%***********************]  1 of 1 completed
# HDFCBANK.NS
# [*********************100%***********************]  1 of 1 completed
# HDFCLIFE.NS
# [*********************100%***********************]  1 of 1 completed
# HEROMOTOCO.NS
# [*********************100%***********************]  1 of 1 completed
# HINDALCO.NS
# [*********************100%***********************]  1 of 1 completed
# HINDCOPPER.NS
# [*********************100%***********************]  1 of 1 completed
# HINDPETRO.NS
# [*********************100%***********************]  1 of 1 completed
# HINDUNILVR.NS
# [*********************100%***********************]  1 of 1 completed
# HONAUT.NS
# [*********************100%***********************]  1 of 1 completed
# IBULHSGFIN.NS
# [*********************100%***********************]  1 of 1 completed
# ICICIBANK.NS
# [*********************100%***********************]  1 of 1 completed
# ICICIGI.NS
# [*********************100%***********************]  1 of 1 completed
# ICICIPRULI.NS
# [*********************100%***********************]  1 of 1 completed
# IDEA.NS
# [*********************100%***********************]  1 of 1 completed
# IDFC.NS
# [*********************100%***********************]  1 of 1 completed
# IDFCFIRSTB.NS
# [*********************100%***********************]  1 of 1 completed
# IEX.NS
# [*********************100%***********************]  1 of 1 completed
# IGL.NS
# [*********************100%***********************]  1 of 1 completed
# INDHOTEL.NS
# [*********************100%***********************]  1 of 1 completed
# INDIACEM.NS
# [*********************100%***********************]  1 of 1 completed
# INDIAMART.NS
# [*********************100%***********************]  1 of 1 completed
# INDIGO.NS
# [*********************100%***********************]  1 of 1 completed
# INDUSINDBK.NS
# [*********************100%***********************]  1 of 1 completed
# INDUSTOWER.NS
# [*********************100%***********************]  1 of 1 completed
# INFY.NS
# [*********************100%***********************]  1 of 1 completed
# INTELLECT.NS
# [*********************100%***********************]  1 of 1 completed
# IOC.NS
# [*********************100%***********************]  1 of 1 completed
# IPCALAB.NS
# [*********************100%***********************]  1 of 1 completed
# IRCTC.NS
# [*********************100%***********************]  1 of 1 completed
# ITC.NS
# [*********************100%***********************]  1 of 1 completed
# JINDALSTEL.NS
# [*********************100%***********************]  1 of 1 completed
# JKCEMENT.NS
# [*********************100%***********************]  1 of 1 completed
# JSWSTEEL.NS
# [*********************100%***********************]  1 of 1 completed
# JUBLFOOD.NS
# [*********************100%***********************]  1 of 1 completed
# KOTAKBANK.NS
# [*********************100%***********************]  1 of 1 completed
# L&TFH.NS
# [*********************100%***********************]  1 of 1 completed
# LALPATHLAB.NS
# [*********************100%***********************]  1 of 1 completed
# LAURUSLABS.NS
# [*********************100%***********************]  1 of 1 completed
# LICHSGFIN.NS
# [*********************100%***********************]  1 of 1 completed
# LT.NS
# [*********************100%***********************]  1 of 1 completed
# LTI.NS
# [*********************100%***********************]  1 of 1 completed
# LTTS.NS
# [*********************100%***********************]  1 of 1 completed
# LUPIN.NS
# [*********************100%***********************]  1 of 1 completed
# M&M.NS
# [*********************100%***********************]  1 of 1 completed
# M&MFIN.NS
# [*********************100%***********************]  1 of 1 completed
# MANAPPURAM.NS
# [*********************100%***********************]  1 of 1 completed
# MARICO.NS
# [*********************100%***********************]  1 of 1 completed
# MARUTI.NS
# [*********************100%***********************]  1 of 1 completed
# MCDOWELL-N.NS
# [*********************100%***********************]  1 of 1 completed
# MCX.NS
# [*********************100%***********************]  1 of 1 completed
# METROPOLIS.NS
# [*********************100%***********************]  1 of 1 completed
# MFSL.NS
# [*********************100%***********************]  1 of 1 completed
# MGL.NS
# [*********************100%***********************]  1 of 1 completed
# MINDTREE.NS
# [*********************100%***********************]  1 of 1 completed
# MOTHERSUMI.NS
# [*********************100%***********************]  1 of 1 completed
# MPHASIS.NS
# [*********************100%***********************]  1 of 1 completed
# MRF.NS
# [*********************100%***********************]  1 of 1 completed
# MUTHOOTFIN.NS
# [*********************100%***********************]  1 of 1 completed
# NAM-INDIA.NS
# [*********************100%***********************]  1 of 1 completed
# NATIONALUM.NS
# [*********************100%***********************]  1 of 1 completed
# NAUKRI.NS
# [*********************100%***********************]  1 of 1 completed
# NAVINFLUOR.NS
# [*********************100%***********************]  1 of 1 completed
# NBCC.NS
# [*********************100%***********************]  1 of 1 completed
# NESTLEIND.NS
# [*********************100%***********************]  1 of 1 completed
# NMDC.NS
# [*********************100%***********************]  1 of 1 completed
# NTPC.NS
# [*********************100%***********************]  1 of 1 completed
# OBEROIRLTY.NS
# [*********************100%***********************]  1 of 1 completed
# OFSS.NS
# [*********************100%***********************]  1 of 1 completed
# ONGC.NS
# [*********************100%***********************]  1 of 1 completed
# PAGEIND.NS
# [*********************100%***********************]  1 of 1 completed
# PEL.NS
# [*********************100%***********************]  1 of 1 completed
# PERSISTENT.NS
# [*********************100%***********************]  1 of 1 completed
# PETRONET.NS
# [*********************100%***********************]  1 of 1 completed
# PFC.NS
# [*********************100%***********************]  1 of 1 completed
# PFIZER.NS
# [*********************100%***********************]  1 of 1 completed
# PIDILITIND.NS
# [*********************100%***********************]  1 of 1 completed
# PIIND.NS
# [*********************100%***********************]  1 of 1 completed
# PNB.NS
# [*********************100%***********************]  1 of 1 completed
# POLYCAB.NS
# [*********************100%***********************]  1 of 1 completed
# POWERGRID.NS
# [*********************100%***********************]  1 of 1 completed
# PVR.NS
# [*********************100%***********************]  1 of 1 completed
# RAIN.NS
# [*********************100%***********************]  1 of 1 completed
# RAMCOCEM.NS
# [*********************100%***********************]  1 of 1 completed
# RBLBANK.NS
# [*********************100%***********************]  1 of 1 completed
# RECLTD.NS
# [*********************100%***********************]  1 of 1 completed
# RELIANCE.NS
# [*********************100%***********************]  1 of 1 completed
# SAIL.NS
# [*********************100%***********************]  1 of 1 completed
# SBICARD.NS
# [*********************100%***********************]  1 of 1 completed
# SBILIFE.NS
# [*********************100%***********************]  1 of 1 completed
# SBIN.NS
# [*********************100%***********************]  1 of 1 completed
# SHREECEM.NS
# [*********************100%***********************]  1 of 1 completed
# SIEMENS.NS
# [*********************100%***********************]  1 of 1 completed
# SRF.NS
# [*********************100%***********************]  1 of 1 completed
# SRTRANSFIN.NS
# [*********************100%***********************]  1 of 1 completed
# STAR.NS
# [*********************100%***********************]  1 of 1 completed
# SUNPHARMA.NS
# [*********************100%***********************]  1 of 1 completed
# SUNTV.NS
# [*********************100%***********************]  1 of 1 completed
# SYNGENE.NS
# [*********************100%***********************]  1 of 1 completed
# TATACHEM.NS
# [*********************100%***********************]  1 of 1 completed
# TATACOMM.NS
# [*********************100%***********************]  1 of 1 completed
# TATACONSUM.NS
# [*********************100%***********************]  1 of 1 completed
# TATAMOTORS.NS
# [*********************100%***********************]  1 of 1 completed
# TATAPOWER.NS
# [*********************100%***********************]  1 of 1 completed
# TATASTEEL.NS
# [*********************100%***********************]  1 of 1 completed
# TCS.NS
# [*********************100%***********************]  1 of 1 completed
# TECHM.NS
# [*********************100%***********************]  1 of 1 completed
# TITAN.NS
# [*********************100%***********************]  1 of 1 completed
# TORNTPHARM.NS
# [*********************100%***********************]  1 of 1 completed
# TORNTPOWER.NS
# [*********************100%***********************]  1 of 1 completed
# TRENT.NS
# [*********************100%***********************]  1 of 1 completed
# TVSMOTOR.NS
# [*********************100%***********************]  1 of 1 completed
# UBL.NS
# [*********************100%***********************]  1 of 1 completed
# ULTRACEMCO.NS
# [*********************100%***********************]  1 of 1 completed
# UPL.NS
# [*********************100%***********************]  1 of 1 completed
# VEDL.NS
# [*********************100%***********************]  1 of 1 completed
# VOLTAS.NS
# [*********************100%***********************]  1 of 1 completed
# WHIRLPOOL.NS
# [*********************100%***********************]  1 of 1 completed
# WIPRO.NS
# [*********************100%***********************]  1 of 1 completed
# ZEEL.NS
# [*********************100%***********************]  1 of 1 completed
# ZYDUSLIFE
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ZYDUSLIFE: No data found, symbol may be delisted

# %% [markdown]
# Here we can't get the prices for ZYDUSLIFE as it was probably delisted from the exchange.

# %% [markdown]
# Here we get the different dates for which the prices were available for the stocks. We are doing this because we'll be storing prices for each symbol on a daily basis.

# %%
# Storing all the dates in a set
dates = set()

for stock_data in stocks_data:
  for date in stock_data.index:
    dates.add(date)

dates = list(dates)
dates.sort()

# %% [markdown]
# Now we will alot the prices for each symbol to the day it belongs to.

# %%
# Creating a prices dictionary and alotting prices to it
prices = {}

for date in dates:
  prices[date] = []

for date in dates:
  for stock_data in stocks_data:
    try:
      prices[date].append(stock_data[date])
    except:
      prices[date].append(None)

# %% [markdown]
# ---
#
# Now that we have the prices stored on a daily basis, we can convert the dictionary they are stored in into a pandas dataframe.

# %%
# Converting dictionary to dataframe
fNo_stocks_close_df = pd.DataFrame(data = list(prices.values()), index = list(prices.keys()), columns = fNo_stocks)

# %% [markdown]
# Now we'll convert the dataframe we got into a correlation dataframe.

# %%
# Printing the correlation dataframe
fNo_stocks_corr_df = round(fNo_stocks_close_df.corr(), 2)
fNo_stocks_corr_df
# Out:
# Stock Symbol   AARTIIND.NS  ABB.NS  ABBOTINDIA.NS  ABCAPITAL.NS  ABFRL.NS  \
# Stock Symbol
# AARTIIND.NS           1.00    0.68           0.96         -0.23      0.65
# ABB.NS                0.68    1.00           0.66          0.36      0.75
# ABBOTINDIA.NS         0.96    0.66           1.00         -0.55      0.55
# ABCAPITAL.NS         -0.23    0.36          -0.55          1.00      0.03
# ABFRL.NS              0.65    0.75           0.55          0.03      1.00
# ...                    ...     ...            ...           ...       ...
# VEDL.NS               0.32    0.68           0.28          0.79      0.14
# VOLTAS.NS             0.95    0.82           0.93          0.04      0.69
# WHIRLPOOL.NS          0.90    0.72           0.94         -0.43      0.54
# WIPRO.NS              0.91    0.76           0.87         -0.02      0.59
# ZEEL.NS               0.39    0.72           0.40          0.75      0.01
#
# Stock Symbol   ACC.NS  ADANIENT.NS  ADANIPORTS.NS  ALKEM.NS  AMARAJABAT.NS  \
# Stock Symbol
# AARTIIND.NS      0.71         0.86           0.92      0.93           0.63
# ABB.NS           0.88         0.56           0.86      0.53           0.76
# ABBOTINDIA.NS    0.71         0.76           0.86      0.89           0.69
# ABCAPITAL.NS     0.35         0.01           0.20     -0.15           0.38
# ABFRL.NS         0.60         0.59           0.65      0.46           0.26
# ...               ...          ...            ...       ...            ...
# VEDL.NS          0.64         0.37           0.21      0.40           0.36
# VOLTAS.NS        0.82         0.80           0.96      0.90           0.73
# WHIRLPOOL.NS     0.76         0.60           0.86      0.77           0.80
# WIPRO.NS         0.84         0.89           0.92      0.87           0.65
# ZEEL.NS          0.75         0.13           0.43     -0.61           0.88
#
# Stock Symbol   ...  TRENT.NS  TVSMOTOR.NS  UBL.NS  ULTRACEMCO.NS  UPL.NS  \
# Stock Symbol   ...
# AARTIIND.NS    ...      0.98         0.82    0.79           0.91    0.89
# ABB.NS         ...      0.69         0.76    0.79           0.81    0.82
# ABBOTINDIA.NS  ...      0.96         0.80    0.78           0.90    0.86
# ABCAPITAL.NS   ...     -0.23         0.84   -0.04           0.11    0.13
# ABFRL.NS       ...      0.63         0.55    0.74           0.67    0.73
# ...            ...       ...          ...     ...            ...     ...
# VEDL.NS        ...      0.36         0.47   -0.06           0.44    0.44
# VOLTAS.NS      ...      0.96         0.90    0.81           0.95    0.94
# WHIRLPOOL.NS   ...      0.90         0.91    0.83           0.92    0.93
# WIPRO.NS       ...      0.92         0.77    0.76           0.91    0.84
# ZEEL.NS        ...      0.39         0.78    0.58           0.68    0.71
#
# Stock Symbol   VEDL.NS  VOLTAS.NS  WHIRLPOOL.NS  WIPRO.NS  ZEEL.NS
# Stock Symbol
# AARTIIND.NS       0.32       0.95          0.90      0.91     0.39
# ABB.NS            0.68       0.82          0.72      0.76     0.72
# ABBOTINDIA.NS     0.28       0.93          0.94      0.87     0.40
# ABCAPITAL.NS      0.79       0.04         -0.43     -0.02     0.75
# ABFRL.NS          0.14       0.69          0.54      0.59     0.01
# ...                ...        ...           ...       ...      ...
# VEDL.NS           1.00       0.49          0.34      0.64     0.47
# VOLTAS.NS         0.49       1.00          0.93      0.92     0.56
# WHIRLPOOL.NS      0.34       0.93          1.00      0.80     0.59
# WIPRO.NS          0.64       0.92          0.80      1.00     0.46
# ZEEL.NS           0.47       0.56          0.59      0.46     1.00
#
# [199 rows x 199 columns]

# %% [markdown]
# I wanted to get the heatmap for this dataframe but cause the dataframe has 199 rows and columns, getting a heatmap of the correct size (with correlational coefficient printed in a readable format) is not possible.

# %% [markdown]
# Finally we have the correlations of each stock stored in a dataframe.
#
# You can try out many different methods to get the most correlated stocks from this dataframe, and can research about the reasons behind this correlation.

# %% [markdown]
# ---
#
# #END OF THE PROJECT

# %% [markdown]
# If you want to save the dataframe as a `.csv` file uncomment the code below and run it.

# %%
# fNo_stocks_corr_df.to_excel("F&O Stocks Correlation.xlsx")
